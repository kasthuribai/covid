# %%
conda install -c anaconda beautifulsoup4
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\USER\Documents\GitHub\covid\env
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.8.2       |           py38_0         162 KB  anaconda
#     ca-certificates-2020.1.1   |                0         165 KB  anaconda
#     certifi-2019.11.28         |           py38_0         157 KB  anaconda
#     openssl-1.1.1              |       he774522_0         5.7 MB  anaconda
#     soupsieve-1.9.5            |           py38_0          61 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         6.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     anaconda/win-64::beautifulsoup4-4.8.2-py38_0
#   soupsieve          anaconda/win-64::soupsieve-1.9.5-py38_0
#
# The following packages will be UPDATED:
#
#   openssl              pkgs/main::openssl-1.1.1d-he774522_4 --> anaconda::openssl-1.1.1-he774522_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# soupsieve-1.9.5      | 61 KB     |            |   0%
# soupsieve-1.9.5      | 61 KB     | ##6        |  26%
# soupsieve-1.9.5      | 61 KB     | ########## | 100%
#
# openssl-1.1.1        | 5.7 MB    |            |   0%
# openssl-1.1.1        | 5.7 MB    | 1          |   2%
# openssl-1.1.1        | 5.7 MB    | 4          |   4%
# openssl-1.1.1        | 5.7 MB    | 7          |   7%
# openssl-1.1.1        | 5.7 MB    | #1         |  11%
# openssl-1.1.1        | 5.7 MB    | #4         |  14%
# openssl-1.1.1        | 5.7 MB    | #7         |  18%
# openssl-1.1.1        | 5.7 MB    | ##1        |  21%
# openssl-1.1.1        | 5.7 MB    | ##4        |  25%
# openssl-1.1.1        | 5.7 MB    | ##7        |  28%
# openssl-1.1.1        | 5.7 MB    | ###        |  31%
# openssl-1.1.1        | 5.7 MB    | ###3       |  34%
# openssl-1.1.1        | 5.7 MB    | ###7       |  37%
# openssl-1.1.1        | 5.7 MB    | ####       |  40%
# openssl-1.1.1        | 5.7 MB    | ####3      |  43%
# openssl-1.1.1        | 5.7 MB    | ####6      |  47%
# openssl-1.1.1        | 5.7 MB    | ####9      |  50%
# openssl-1.1.1        | 5.7 MB    | #####3     |  53%
# openssl-1.1.1        | 5.7 MB    | #####6     |  57%
# openssl-1.1.1        | 5.7 MB    | #####9     |  60%
# openssl-1.1.1        | 5.7 MB    | ######3    |  63%
# openssl-1.1.1        | 5.7 MB    | ######6    |  67%
# openssl-1.1.1        | 5.7 MB    | ######9    |  70%
# openssl-1.1.1        | 5.7 MB    | #######3   |  73%
# openssl-1.1.1        | 5.7 MB    | #######6   |  77%
# openssl-1.1.1        | 5.7 MB    | ########   |  80%
# openssl-1.1.1        | 5.7 MB    | ########3  |  83%
# openssl-1.1.1        | 5.7 MB    | ########6  |  87%
# openssl-1.1.1        | 5.7 MB    | ########9  |  90%
# openssl-1.1.1        | 5.7 MB    | #########3 |  93%
# openssl-1.1.1        | 5.7 MB    | #########7 |  97%
# openssl-1.1.1        | 5.7 MB    | ########## | 100%
#
# certifi-2019.11.28   | 157 KB    |            |   0%
# certifi-2019.11.28   | 157 KB    | ##         |  20%
# certifi-2019.11.28   | 157 KB    | ########## | 100%
#
# beautifulsoup4-4.8.2 | 162 KB    |            |   0%
# beautifulsoup4-4.8.2 | 162 KB    | #9         |  20%
# beautifulsoup4-4.8.2 | 162 KB    | ########## | 100%
#
# ca-certificates-2020 | 165 KB    |            |   0%
# ca-certificates-2020 | 165 KB    | #####8     |  58%
# ca-certificates-2020 | 165 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda install -c anaconda keras
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#
# Note: you may need to restart the kernel to use updated packages.failed
# Finding conflicts:   0%|          | 0/124 [00:00<?, ?it/s]
# Examining google-auth-oauthlib:   0%|          | 0/124 [00:00<?, ?it/s]
# Examining requests-oauthlib:   1%|          | 1/124 [00:00<?, ?it/s]
# Examining scipy:   2%|1         | 2/124 [00:00<?, ?it/s]
# Examining mkl_random:   2%|2         | 3/124 [00:00<?, ?it/s]
# Examining pbr:   3%|3         | 4/124 [00:00<?, ?it/s]
# Examining packaging:   4%|4         | 5/124 [00:00<?, ?it/s]
# Examining vs2010_runtime:   5%|4         | 6/124 [00:00<?, ?it/s]
# Examining wheel:   6%|5         | 7/124 [00:00<?, ?it/s]
# Examining enum34:   6%|6         | 8/124 [00:00<?, ?it/s]
# Examining pyjwt:   7%|7         | 9/124 [00:00<?, ?it/s]
# Examining vs2008_runtime:   8%|8         | 10/124 [00:00<?, ?it/s]
# Examining google-pasta:   9%|8         | 11/124 [00:00<?, ?it/s]
# Examining scikit-learn:  10%|9         | 12/124 [00:00<?, ?it/s]
# Examining distlib:  10%|#         | 13/124 [00:00<?, ?it/s]
# Examining pyflakes:  11%|#1        | 14/124 [00:00<?, ?it/s]
# Examining pep8-naming:  12%|#2        | 15/124 [00:00<?, ?it/s]
# Examining mkl-rt:  13%|#2        | 16/124 [00:00<?, ?it/s]
# Examining h5py:  14%|#3        | 17/124 [00:00<?, ?it/s]
# Examining argparse:  15%|#4        | 18/124 [00:00<?, ?it/s]
# Examining linecache2:  15%|#5        | 19/124 [00:00<?, ?it/s]
# Examining mccabe:  16%|#6        | 20/124 [00:00<?, ?it/s]
# Examining python:  17%|#6        | 21/124 [00:00<00:00, 21041.66it/s]
# Examining _tflow_select:  18%|#7        | 22/124 [00:00<00:00, 22043.64it/s]
# Examining cachecontrol:  19%|#8        | 23/124 [00:00<00:00, 23045.63it/s]
# Examining distribute:  19%|#9        | 24/124 [00:00<00:00, 24047.61it/s]
# Examining wrapt:  20%|##        | 25/124 [00:00<00:00, 25049.59it/s]
# Examining numexpr:  21%|##        | 26/124 [00:00<00:00, 26051.58it/s]
# Examining libmklml:  22%|##1       | 27/124 [00:00<00:00, 27053.56it/s]
# Examining cachetools:  23%|##2       | 28/124 [00:00<00:00, 28055.55it/s]
# Examining yaml:  23%|##3       | 29/124 [00:00<00:00, 29057.53it/s]
# Examining backports:  24%|##4       | 30/124 [00:00<00:00, 30059.51it/s]
# Examining colorama:  25%|##5       | 31/124 [00:00<00:00, 31061.50it/s]
# Examining pycparser:  26%|##5       | 32/124 [00:00<00:00, 32063.48it/s]
# Examining libprotobuf:  27%|##6       | 33/124 [00:00<00:00, 33065.46it/s]
# Examining pyasn1:  27%|##7       | 34/124 [00:00<00:00, 34067.45it/s]
# Examining hdf5:  28%|##8       | 35/124 [00:00<00:00, 35069.43it/s]
# Examining flake8-import-order:  29%|##9       | 36/124 [00:00<00:00, 36071.42it/s]
# Examining pip:  30%|##9       | 37/124 [00:00<00:00, 37073.40it/s]
# Examining _tflow_190_select:  31%|###       | 38/124 [00:00<00:00, 38075.38it/s]
# Examining ipaddress:  31%|###1      | 39/124 [00:00<00:00, 39077.37it/s]
# Examining funcsigs:  32%|###2      | 40/124 [00:00<00:00, 40079.35it/s]
# Examining rsa:  33%|###3      | 41/124 [00:00<00:00, 41081.33it/s]
# Examining keras-applications:  34%|###3      | 42/124 [00:00<00:00, 42083.32it/s]
# Examining vs2013_runtime:  35%|###4      | 43/124 [00:00<00:00, 43085.30it/s]
# Examining blas:  35%|###5      | 44/124 [00:00<00:00, 44087.29it/s]
# Examining cryptography:  36%|###6      | 45/124 [00:00<00:00, 45089.27it/s]
# Examining pyyaml:  37%|###7      | 46/124 [00:00<00:00, 46091.25it/s]
# Examining pyasn1-modules:  38%|###7      | 47/124 [00:00<00:00, 47093.24it/s]
# Examining click:  39%|###8      | 48/124 [00:00<00:00, 48095.22it/s]
# Examining tbb4py:  40%|###9      | 49/124 [00:00<00:00, 49097.20it/s]
# Examining absl-py:  40%|####      | 50/124 [00:00<00:00, 50099.19it/s]
# Examining blinker:  41%|####1     | 51/124 [00:00<00:00, 51101.17it/s]
# Examining _tflow_1100_select:  42%|####1     | 52/124 [00:00<00:00, 52103.16it/s]
# Examining tensorflow-estimator:  43%|####2     | 53/124 [00:00<00:00, 53105.14it/s]
# Examining bleach:  44%|####3     | 54/124 [00:00<00:00, 54107.12it/s]
# Examining keras-base:  44%|####4     | 55/124 [00:00<00:00, 55109.11it/s]
# Examining intel-openmp:  45%|####5     | 56/124 [00:00<00:00, 56111.09it/s]
# Examining opt_einsum:  46%|####5     | 57/124 [00:00<00:00, 57113.07it/s]
# Examining termcolor:  47%|####6     | 58/124 [00:00<00:00, 58115.06it/s]
# Examining cryptography-vectors:  48%|####7     | 59/124 [00:00<00:00, 59117.04it/s]
# Examining pyreadline:  48%|####8     | 60/124 [00:00<00:00, 60119.03it/s]
# Examining tensorboard:  49%|####9     | 61/124 [00:00<00:00, 61121.01it/s]
# Examining zlib:  50%|#####     | 62/124 [00:00<00:00, 31080.06it/s]
# Examining progress:  51%|#####     | 63/124 [00:00<00:00, 31581.35it/s]
# Examining functools32:  52%|#####1    | 64/124 [00:00<00:00, 32082.64it/s]
# Examining flake8:  52%|#####2    | 65/124 [00:00<00:00, 32583.93it/s]
# Examining mkl-service:  53%|#####3    | 66/124 [00:00<00:00, 33085.22it/s]
# Examining futures:  54%|#####4    | 67/124 [00:00<00:00, 33586.51it/s]
# Examining ordereddict:  55%|#####4    | 68/124 [00:00<00:00, 34087.81it/s]
# Examining werkzeug:  56%|#####5    | 69/124 [00:00<00:00, 34589.10it/s]
# Examining tensorflow:  56%|#####6    | 70/124 [00:00<00:00, 35090.39it/s]
# Examining tensorflow-base:  57%|#####7    | 71/124 [00:00<00:00, 35591.68it/s]
# Examining openssl:  58%|#####8    | 72/124 [00:00<00:00, 36092.97it/s]
# Examining msgpack-python:  59%|#####8    | 73/124 [00:00<00:00, 36594.26it/s]
# Examining unittest2:  60%|#####9    | 74/124 [00:00<00:00, 37095.55it/s]
# Examining gast:  60%|######    | 75/124 [00:00<00:00, 37596.84it/s]
# Examining cudnn:  61%|######1   | 76/124 [00:00<00:00, 38098.14it/s]
# Examining msvc_runtime:  62%|######2   | 77/124 [00:00<00:00, 38599.43it/s]
# Examining lockfile:  63%|######2   | 78/124 [00:00<00:00, 39100.72it/s]
# Examining configparser:  64%|######3   | 79/124 [00:00<00:00, 39602.01it/s]
# Examining asn1crypto:  65%|######4   | 80/124 [00:00<00:00, 40103.30it/s]
# Examining six:  65%|######5   | 81/124 [00:00<00:00, 40604.59it/s]
# Examining vc:  66%|######6   | 82/124 [00:00<00:00, 41105.88it/s]
# Examining nose:  67%|######6   | 83/124 [00:00<00:00, 41607.17it/s]
# Examining ca-certificates:  68%|######7   | 84/124 [00:00<00:00, 42108.47it/s]
# Examining google-auth:  69%|######8   | 85/124 [00:00<00:00, 42609.76it/s]
# Examining keras-preprocessing:  69%|######9   | 86/124 [00:00<00:00, 43111.05it/s]
# Examining mkl_fft:  70%|#######   | 87/124 [00:00<00:00, 43612.34it/s]
# Examining flake8-polyfill:  71%|#######   | 88/124 [00:00<00:00, 44113.63it/s]
# Examining oauthlib:  72%|#######1  | 89/124 [00:00<00:00, 44614.92it/s]
# Examining vs2015_runtime:  73%|#######2  | 90/124 [00:00<00:00, 45116.21it/s]
# Examining html5lib:  73%|#######3  | 91/124 [00:00<00:00, 45617.50it/s]
# Examining requests:  74%|#######4  | 92/124 [00:00<00:00, 46118.80it/s]
# Examining pep8:  75%|#######5  | 93/124 [00:00<00:00, 46620.09it/s]
# Examining traceback2:  76%|#######5  | 94/124 [00:00<00:00, 47121.38it/s]
# Examining entrypoints:  77%|#######6  | 95/124 [00:00<00:00, 47622.67it/s]
# Examining numpy:  77%|#######7  | 96/124 [00:00<00:00, 48123.96it/s]
# Examining keras:  78%|#######8  | 97/124 [00:00<00:00, 48625.25it/s]
# Examining wincertstore:  79%|#######9  | 98/124 [00:00<00:00, 49126.54it/s]
# Examining certifi:  80%|#######9  | 99/124 [00:00<00:00, 49627.84it/s]
# Examining win_inet_pton:  81%|########  | 100/124 [00:00<00:00, 50129.13it/s]
# Examining grpcio:  81%|########1 | 101/124 [00:00<00:00, 50630.42it/s]
# Examining urllib3:  82%|########2 | 102/124 [00:00<00:00, 34089.16it/s]
# Examining tbb:  83%|########3 | 103/124 [00:00<00:00, 34423.37it/s]
# Examining cffi:  84%|########3 | 104/124 [00:00<00:00, 34757.58it/s]
# Examining icc_rt:  85%|########4 | 105/124 [00:00<00:00, 35091.79it/s]
# Examining markdown:  85%|########5 | 106/124 [00:00<00:00, 35425.99it/s]
# Examining sqlite:  86%|########6 | 107/124 [00:00<00:00, 35760.20it/s]
# Examining mkl:  87%|########7 | 108/124 [00:00<00:00, 36094.41it/s]
# Examining numpy-base:  88%|########7 | 109/124 [00:00<00:00, 36428.62it/s]
# Examining pycodestyle:  89%|########8 | 110/124 [00:00<00:00, 36762.82it/s]
# Examining backports.weakref:  90%|########9 | 111/124 [00:00<00:00, 37097.03it/s]
# Examining mock:  90%|######### | 112/124 [00:00<00:00, 37431.24it/s]
# Examining cudatoolkit:  91%|#########1| 113/124 [00:00<00:00, 37765.45it/s]
# Examining webencodings:  92%|#########1| 114/124 [00:00<00:00, 38099.65it/s]
# Examining chardet:  93%|#########2| 115/124 [00:00<00:00, 38433.86it/s]
# Examining pyopenssl:  94%|#########3| 116/124 [00:00<00:00, 38768.07it/s]
# Examining idna:  94%|#########4| 117/124 [00:00<00:00, 39102.28it/s]
# Examining astor:  95%|#########5| 118/124 [00:00<00:00, 39436.48it/s]
# Examining pyparsing:  96%|#########5| 119/124 [00:00<00:00, 39770.69it/s]
# Examining protobuf:  97%|#########6| 120/124 [00:00<00:00, 40104.90it/s]
# Examining typing:  98%|#########7| 121/124 [00:00<00:00, 40439.11it/s]
# Examining pysocks:  98%|#########8| 122/124 [00:00<00:00, 40773.31it/s]
# Examining setuptools:  99%|#########9| 123/124 [00:00<00:00, 41107.52it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - keras -> python[version='>=3.5,<3.6.0a0|>=3.6,<3.7.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
#
#
# Package six conflicts for:
# keras -> six[version='>=1.9.0']
# Package keras-base conflicts for:
# keras -> keras-base[version='2.2.0.*|2.2.2.*|2.2.4.*|2.3.1.*']
# Package h5py conflicts for:
# keras -> h5py
# Package sqlite conflicts for:
# python=3.8 -> sqlite[version='>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0']
# Package vs2015_runtime conflicts for:
# python=3.8 -> vs2015_runtime[version='>=14.16.27012,<15.0a0']
# Package pip conflicts for:
# python=3.8 -> pip
# Package scipy conflicts for:
# keras -> scipy[version='>=0.14']
# Package openssl conflicts for:
# python=3.8 -> openssl[version='>=1.1.1d,<1.1.2a']
# Package pyyaml conflicts for:
# keras -> pyyaml
# Package numpy conflicts for:
# keras -> numpy[version='>=1.9.1']
# Package vc conflicts for:
# python=3.8 -> vc[version='>=14.1,<15.0a0']
# Package tensorflow conflicts for:
# keras -> tensorflow[version='<2.0']

# %%
conda install -c conda-forge keras tensorflow
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Finding conflicts:   0%|          | 0/164 [00:00<?, ?it/s]
# Examining m2w64-windows-default-manifest:   0%|          | 0/164 [00:00<?, ?it/s]
# Examining theano:   1%|          | 1/164 [00:00<00:00, 1072.71it/s]
# Examining msgpack-python:   1%|1         | 2/164 [00:00<00:00, 2145.42it/s]
# Examining google-auth:   2%|1         | 3/164 [00:00<00:00, 3218.14it/s]
# Examining cython:   2%|2         | 4/164 [00:00<00:00, 4290.85it/s]
# Examining google-pasta:   3%|3         | 5/164 [00:00<00:00, 5363.56it/s]
# Examining m2w64-bzip2:   4%|3         | 6/164 [00:00<00:00, 6436.27it/s]
# Examining enum34:   4%|4         | 7/164 [00:00<00:00, 7508.98it/s]
# Examining mkl_random:   5%|4         | 8/164 [00:00<00:00, 8581.70it/s]
# Examining oauthlib:   5%|5         | 9/164 [00:00<00:00, 9654.41it/s]
# Examining ipaddress:   6%|6         | 10/164 [00:00<00:00, 10727.12it/s]
# Examining urllib3:   7%|6         | 11/164 [00:00<00:00, 11799.83it/s]
# Examining packaging:   7%|7         | 12/164 [00:00<00:00, 12872.54it/s]
# Examining termcolor:   8%|7         | 13/164 [00:00<00:00, 13945.26it/s]
# Examining pycparser:   9%|8         | 14/164 [00:00<00:00, 15017.97it/s]
# Examining m2w64-headers-git:   9%|9         | 15/164 [00:00<00:00, 16090.68it/s]
# Examining libblas:  10%|9         | 16/164 [00:00<00:00, 17163.39it/s]
# Examining libopenblas:  10%|#         | 17/164 [00:00<00:00, 18236.10it/s]
# Examining m2w64-crt-git:  11%|#         | 18/164 [00:00<00:00, 19308.82it/s]
# Examining python:  12%|#1        | 19/164 [00:00<00:00, 20381.53it/s]
# Examining m2w64-pkg-config:  12%|#2        | 20/164 [00:00<00:00, 21454.24it/s]
# Examining sqlite:  13%|#2        | 21/164 [00:00<00:00, 22526.95it/s]
# Examining vs2013_runtime:  13%|#3        | 22/164 [00:00<00:00, 23599.66it/s]
# Examining cachecontrol:  14%|#4        | 23/164 [00:00<00:00, 24672.38it/s]
# Examining m2w64-libiconv:  15%|#4        | 24/164 [00:00<00:00, 25745.09it/s]
# Examining typing:  15%|#5        | 25/164 [00:00<00:00, 26817.80it/s]
# Examining protobuf:  16%|#5        | 26/164 [00:00<00:00, 27890.51it/s]
# Examining markupsafe:  16%|#6        | 27/164 [00:00<00:00, 28963.22it/s]
# Examining m2w64-libwinpthread-git:  17%|#7        | 28/164 [00:00<00:00, 30035.94it/s]
# Examining tbb:  18%|#7        | 29/164 [00:00<00:00, 31108.65it/s]
# Examining setuptools:  18%|#8        | 30/164 [00:00<00:00, 32181.36it/s]
# Examining requests-oauthlib:  19%|#8        | 31/164 [00:00<00:00, 33254.07it/s]
# Examining cffi:  20%|#9        | 32/164 [00:00<00:00, 34326.78it/s]
# Examining html5lib:  20%|##        | 33/164 [00:00<00:00, 17106.91it/s]
# Examining mkl-service:  21%|##        | 34/164 [00:00<00:00, 17625.30it/s]
# Examining m2w64-gcc:  21%|##1       | 35/164 [00:00<00:00, 18143.70it/s]
# Examining blas:  22%|##1       | 36/164 [00:00<00:00, 18662.09it/s]
# Examining cryptography:  23%|##2       | 37/164 [00:00<00:00, 19180.48it/s]
# Examining tensorboard:  23%|##3       | 38/164 [00:00<00:00, 19698.87it/s]
# Examining openssl:  24%|##3       | 39/164 [00:00<00:00, 20217.26it/s]
# Examining pep8-naming:  24%|##4       | 40/164 [00:00<00:00, 20735.65it/s]
# Examining libmklml:  25%|##5       | 41/164 [00:00<00:00, 21254.04it/s]
# Examining certifi:  26%|##5       | 42/164 [00:00<00:00, 21772.43it/s]
# Examining tensorflow-estimator:  26%|##6       | 43/164 [00:00<00:00, 22290.83it/s]
# Examining flake8:  27%|##6       | 44/164 [00:00<00:00, 22809.22it/s]
# Examining flake8-polyfill:  27%|##7       | 45/164 [00:00<00:00, 23327.61it/s]
# Examining pyreadline:  28%|##8       | 46/164 [00:00<00:00, 23846.00it/s]
# Examining absl-py:  29%|##8       | 47/164 [00:00<00:00, 24364.39it/s]
# Examining scipy:  29%|##9       | 48/164 [00:00<00:00, 24882.78it/s]
# Examining llvmdev:  30%|##9       | 49/164 [00:00<00:00, 25401.17it/s]
# Examining mock:  30%|###       | 50/164 [00:00<00:00, 25919.56it/s]
# Examining blis:  31%|###1      | 51/164 [00:00<00:00, 26437.96it/s]
# Examining m2w64-gmp:  32%|###1      | 52/164 [00:00<00:00, 26956.35it/s]
# Examining requests:  32%|###2      | 53/164 [00:00<00:00, 27474.74it/s]
# Examining m2w64-gcc-ada:  33%|###2      | 54/164 [00:00<00:00, 27993.13it/s]
# Examining pyasn1:  34%|###3      | 55/164 [00:00<00:00, 28511.52it/s]
# Examining zlib:  34%|###4      | 56/164 [00:00<00:00, 29029.91it/s]
# Examining vs2015_win-64:  35%|###4      | 57/164 [00:00<00:00, 29548.30it/s]
# Examining pyflakes:  35%|###5      | 58/164 [00:00<00:00, 30066.70it/s]
# Examining pyopenssl:  36%|###5      | 59/164 [00:00<00:00, 30585.09it/s]
# Examining pbr:  37%|###6      | 60/164 [00:00<00:00, 31103.48it/s]
# Examining tensorflow:  37%|###7      | 61/164 [00:00<00:00, 31621.87it/s]
# Examining win_inet_pton:  38%|###7      | 62/164 [00:00<00:00, 21186.81it/s]
# Examining numpy:  38%|###8      | 63/164 [00:00<00:00, 21528.53it/s]
# Examining grpcio:  39%|###9      | 64/164 [00:00<00:00, 21870.25it/s]
# Examining mkl:  40%|###9      | 65/164 [00:00<00:00, 22211.97it/s]
# Examining pyyaml:  40%|####      | 66/164 [00:00<00:00, 22553.70it/s]
# Examining libprotobuf:  41%|####      | 67/164 [00:00<00:00, 22895.42it/s]
# Examining openblas:  41%|####1     | 68/164 [00:00<00:00, 23237.14it/s]
# Examining clangdev:  42%|####2     | 69/164 [00:00<00:00, 23578.86it/s]
# Examining gast:  43%|####2     | 70/164 [00:00<00:00, 23920.59it/s]
# Examining libflang:  43%|####3     | 71/164 [00:00<00:00, 24262.31it/s]
# Examining liblapacke:  44%|####3     | 72/164 [00:00<00:00, 24604.03it/s]
# Examining libxml2:  45%|####4     | 73/164 [00:00<00:00, 24945.75it/s]
# Examining progress:  45%|####5     | 74/164 [00:00<00:00, 25287.48it/s]
# Examining chardet:  46%|####5     | 75/164 [00:00<00:00, 25629.20it/s]
# Examining astor:  46%|####6     | 76/164 [00:00<00:00, 25970.92it/s]
# Examining h5py:  47%|####6     | 77/164 [00:00<00:00, 26312.65it/s]
# Examining vs2015_runtime:  48%|####7     | 78/164 [00:00<00:00, 26654.37it/s]
# Examining m2w64-gcc-objc:  48%|####8     | 79/164 [00:00<00:00, 26996.09it/s]
# Examining python_abi:  49%|####8     | 80/164 [00:00<00:00, 27337.81it/s]
# Examining backports:  49%|####9     | 81/164 [00:00<00:00, 27679.54it/s]
# Examining asttokens:  50%|#####     | 82/164 [00:00<00:00, 28021.26it/s]
# Examining colorama:  51%|#####     | 83/164 [00:00<00:00, 28362.98it/s]
# Examining pyjwt:  51%|#####1    | 84/164 [00:00<00:00, 28704.70it/s]
# Examining mccabe:  52%|#####1    | 85/164 [00:00<00:00, 29046.43it/s]
# Examining clang_variant:  52%|#####2    | 86/164 [00:00<00:00, 29388.15it/s]
# Examining m2w64-make:  53%|#####3    | 87/164 [00:00<00:00, 29729.87it/s]
# Examining pip:  54%|#####3    | 88/164 [00:00<00:00, 30071.59it/s]
# Examining libpython:  54%|#####4    | 89/164 [00:00<00:00, 30413.32it/s]
# Examining m2w64-gcc-fortran:  55%|#####4    | 90/164 [00:00<00:00, 30755.04it/s]
# Examining pyasn1-modules:  55%|#####5    | 91/164 [00:00<00:00, 31096.76it/s]
# Examining cudatoolkit:  56%|#####6    | 92/164 [00:00<00:00, 31438.49it/s]
# Examining cudnn:  57%|#####6    | 93/164 [00:00<00:00, 23702.39it/s]
# Examining tbb4py:  57%|#####7    | 94/164 [00:00<00:00, 23957.26it/s]
# Examining msys2-conda-epoch:  58%|#####7    | 95/164 [00:00<00:00, 24212.12it/s]
# Examining google-auth-oauthlib:  59%|#####8    | 96/164 [00:00<00:00, 24466.99it/s]
# Examining pyparsing:  59%|#####9    | 97/164 [00:00<00:00, 24721.85it/s]
# Examining cachetools:  60%|#####9    | 98/164 [00:00<00:00, 24976.71it/s]
# Examining traceback2:  60%|######    | 99/164 [00:00<00:00, 25231.58it/s]
# Examining hdf5:  61%|######    | 100/164 [00:00<00:00, 25486.44it/s]
# Examining m2w64-toolchain:  62%|######1   | 101/164 [00:00<00:00, 25741.31it/s]
# Examining vs2008_win-64:  62%|######2   | 102/164 [00:00<00:00, 25996.17it/s]
# Examining werkzeug:  63%|######2   | 103/164 [00:00<00:00, 26251.04it/s]
# Examining _tflow_select:  63%|######3   | 104/164 [00:00<00:00, 26505.90it/s]
# Examining backports.weakref:  64%|######4   | 105/164 [00:00<00:00, 26760.77it/s]
# Examining six:  65%|######4   | 106/164 [00:00<00:00, 27015.63it/s]
# Examining unittest2:  65%|######5   | 107/164 [00:00<00:00, 27270.49it/s]
# Examining distlib:  66%|######5   | 108/164 [00:00<00:00, 27525.36it/s]
# Examining vc:  66%|######6   | 109/164 [00:00<00:00, 27780.22it/s]
# Examining rsa:  67%|######7   | 110/164 [00:00<00:00, 28035.09it/s]
# Examining blinker:  68%|######7   | 111/164 [00:00<00:00, 28289.95it/s]
# Examining m2w64-mpc:  68%|######8   | 112/164 [00:00<00:00, 28544.82it/s]
# Examining funcsigs:  69%|######8   | 113/164 [00:00<00:00, 28799.68it/s]
# Examining idna:  70%|######9   | 114/164 [00:00<00:00, 29054.55it/s]
# Examining opt_einsum:  70%|#######   | 115/164 [00:00<00:00, 29309.41it/s]
# Examining bleach:  71%|#######   | 116/164 [00:00<00:00, 29564.27it/s]
# Examining click:  71%|#######1  | 117/164 [00:00<00:00, 29819.14it/s]
# Examining numpy-base:  72%|#######1  | 118/164 [00:00<00:00, 30074.00it/s]
# Examining m2w64-tools-git:  73%|#######2  | 119/164 [00:00<00:00, 30328.87it/s]
# Examining libgpuarray:  73%|#######3  | 120/164 [00:00<00:00, 30583.73it/s]
# Examining entrypoints:  74%|#######3  | 121/164 [00:00<00:00, 30838.60it/s]
# Examining linecache2:  74%|#######4  | 122/164 [00:00<00:00, 31093.46it/s]
# Examining liblapack:  75%|#######5  | 123/164 [00:00<00:00, 31348.33it/s]
# Examining mkl_fft:  76%|#######5  | 124/164 [00:00<00:00, 31603.19it/s]
# Examining wrapt:  76%|#######6  | 125/164 [00:00<00:00, 25401.55it/s]
# Examining functools32:  77%|#######6  | 126/164 [00:00<00:00, 25604.76it/s]
# Examining lockfile:  77%|#######7  | 127/164 [00:00<00:00, 25807.98it/s]
# Examining m2w64-winpthreads-git:  78%|#######8  | 128/164 [00:00<00:00, 26011.19it/s]
# Examining tensorflow-base:  79%|#######8  | 129/164 [00:00<00:00, 26214.40it/s]
# Examining asn1crypto:  79%|#######9  | 130/164 [00:00<00:00, 26417.61it/s]
# Examining keras-preprocessing:  80%|#######9  | 131/164 [00:00<00:00, 26620.82it/s]
# Examining intel-openmp:  80%|########  | 132/164 [00:00<00:00, 26824.04it/s]
# Examining m2w64-gcc-libs-core:  81%|########1 | 133/164 [00:00<00:00, 27027.25it/s]
# Examining flake8-import-order:  82%|########1 | 134/164 [00:00<00:00, 27230.46it/s]
# Examining pycodestyle:  82%|########2 | 135/164 [00:00<00:00, 27433.67it/s]
# Examining libcblas:  83%|########2 | 136/164 [00:00<00:00, 27636.89it/s]
# Examining keras-base:  84%|########3 | 137/164 [00:00<00:00, 27840.10it/s]
# Examining wincertstore:  84%|########4 | 138/164 [00:00<00:00, 28043.31it/s]
# Examining pygpu:  85%|########4 | 139/164 [00:00<00:00, 28246.52it/s]
# Examining wheel:  85%|########5 | 140/164 [00:00<00:00, 28449.74it/s]
# Examining m2w64-binutils:  86%|########5 | 141/164 [00:00<00:00, 28652.95it/s]
# Examining webencodings:  87%|########6 | 142/164 [00:00<00:00, 28856.16it/s]
# Examining yaml:  87%|########7 | 143/164 [00:00<00:00, 29059.37it/s]
# Examining keras:  88%|########7 | 144/164 [00:00<00:00, 29262.59it/s]
# Examining vs2008_runtime:  88%|########8 | 145/164 [00:00<00:00, 29465.80it/s]
# Examining configparser:  89%|########9 | 146/164 [00:00<00:00, 29669.01it/s]
# Examining m2w64-gcc-libs:  90%|########9 | 147/164 [00:00<00:00, 29872.22it/s]
# Examining cryptography-vectors:  90%|######### | 148/164 [00:00<00:00, 30075.44it/s]
# Examining keras-applications:  91%|######### | 149/164 [00:00<00:00, 30278.65it/s]
# Examining m2w64-zlib:  91%|#########1| 150/164 [00:00<00:00, 30481.86it/s]
# Examining llvm-meta:  92%|#########2| 151/164 [00:00<00:00, 30685.07it/s]
# Examining pysocks:  93%|#########2| 152/164 [00:00<00:00, 30888.29it/s]
# Examining m2w64-isl:  93%|#########3| 153/164 [00:00<00:00, 31091.50it/s]
# Examining futures:  94%|#########3| 154/164 [00:00<00:00, 31294.71it/s]
# Examining m2w64-gcc-libgfortran:  95%|#########4| 155/164 [00:00<00:00, 31497.92it/s]
# Examining ca-certificates:  95%|#########5| 156/164 [00:00<00:00, 31701.13it/s]
# Examining libiconv:  96%|#########5| 157/164 [00:00<00:00, 31904.35it/s]
# Examining openmp:  96%|#########6| 158/164 [00:00<00:00, 32107.56it/s]
# Examining icc_rt:  97%|#########6| 159/164 [00:00<00:00, 32310.77it/s]
# Examining m2w64-mpfr:  98%|#########7| 160/164 [00:00<00:00, 32513.98it/s]
# Examining m2w64-libmangle-git:  98%|#########8| 161/164 [00:00<00:00, 27202.83it/s]
# Examining markdown:  99%|#########8| 162/164 [00:00<00:00, 27371.79it/s]
# Examining mako:  99%|#########9| 163/164 [00:00<00:00, 27540.75it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - keras -> python[version='2.7.*|3.4.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - tensorflow -> python[version='3.5.*|3.6.*|3.7.*|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
#
#
# Package setuptools conflicts for:
# keras -> setuptools
# Package tensorboard conflicts for:
# tensorflow -> tensorboard[version='1.10.*|1.9.*|>=0.4.0rc1,<0.5.0|>=1.10.0,<1.11.0|>=1.11.0,<1.12.0|>=1.12.0,<1.13.0|>=1.13.0,<1.14.0|>=1.13.0,<1.14.0a0|>=1.14.0,<1.15.0|>=1.15.0|>=1.5.0,<1.6.0|>=1.6.0,<1.7.0|>=1.7.0,<1.8.0|>=1.8.0,<1.9.0|>=1.9.0,<1.10.0|>=2.0.0|>=2.1.0']
# Package mock conflicts for:
# tensorflow -> mock[version='>=2.0.0']
# Package grpcio conflicts for:
# tensorflow -> grpcio[version='>=1.8.6']
# Package werkzeug conflicts for:
# tensorflow -> werkzeug[version='>=0.11.10']
# Package vc conflicts for:
# python=3.8 -> vc[version='>=14.1,<15.0a0']
# Package keras-base conflicts for:
# keras -> keras-base[version='2.2.0.*|2.2.2.*|2.2.4.*|2.3.1.*']
# Package backports.weakref conflicts for:
# tensorflow -> backports.weakref[version='1.0rc1|>=1.0rc1']
# Package six conflicts for:
# keras -> six[version='>=1.9.0']
# tensorflow -> six[version='>=1.10.0']
# Package keras-preprocessing conflicts for:
# keras -> keras-preprocessing[version='1.0.2.*|>=1.0.5|>=1.1.0']
# tensorflow -> keras-preprocessing[version='>=1.0.5']
# Package theano conflicts for:
# keras -> theano
# Package python_abi conflicts for:
# tensorflow -> python_abi=[build='*_cp36m|*_cp35m|*_cp37m']
# keras -> python_abi=[build='*_cp34m|*_cp27m|*_cp35m|*_cp36m|*_cp37m']
# python=3.8 -> python_abi[version='*|3.8.*',build=*_cp38]
# Package tensorflow conflicts for:
# keras -> tensorflow[version='<2.0']
# Package gast conflicts for:
# tensorflow -> gast[version='>=0.2.0']
# Package bleach conflicts for:
# tensorflow -> bleach==1.5.0
# Package keras-applications conflicts for:
# tensorflow -> keras-applications[version='>=1.0.6']
# keras -> keras-applications[version='1.0.4.*|>=1.0.6|>=1.0.8']
# Package absl-py conflicts for:
# tensorflow -> absl-py[version='>=0.1.6']
# Package scipy conflicts for:
# keras -> scipy[version='>=0.14']
# Package h5py conflicts for:
# keras -> h5py
# Package pip conflicts for:
# python=3.8 -> pip
# Package tensorflow-estimator conflicts for:
# tensorflow -> tensorflow-estimator[version='>=1.13.0,<1.14.0a0|>=1.14.0,<1.15.0|>=1.15.0|>=2.0.0|>=2.1.0']
# Package vs2015_runtime conflicts for:
# python=3.8 -> vs2015_runtime[version='>=14.16.27012,<15.0a0']
# Package _tflow_select conflicts for:
# tensorflow -> _tflow_select[version='2.1.0|==2.1.0|2.2.0|==2.2.0|2.3.0|==2.3.0',build='mkl|eigen|gpu|eigen|mkl']
# Package numpy conflicts for:
# keras -> numpy[version='>=1.9.1']
# tensorflow -> numpy[version='>=1.11.0|>=1.12.1|>=1.13.3']
# Package protobuf conflicts for:
# tensorflow -> protobuf[version='3.1.0|>=3.1.0|>=3.2.0|>=3.3.0|>=3.4.0|>=3.6.0|>=3.6.1']
# Package markdown conflicts for:
# tensorflow -> markdown[version='>=2.6.8']
# Package openssl conflicts for:
# python=3.8 -> openssl[version='>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a']
# Package html5lib conflicts for:
# tensorflow -> html5lib==0.9999999
# Package sqlite conflicts for:
# python=3.8 -> sqlite[version='>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0']
# Package pyyaml conflicts for:
# keras -> pyyaml
# Package termcolor conflicts for:
# tensorflow -> termcolor[version='>=1.1.0']
# Package tensorflow-base conflicts for:
# tensorflow -> tensorflow-base[version='1.13.1|1.13.1|1.13.1|1.13.1|1.13.1|==1.10.0|==1.11.0|==1.11.0|==1.11.0|==1.12.0|==1.12.0|==1.12.0|==1.13.1|==1.13.1|==1.13.1|==1.13.1|==1.13.1|==1.13.1|==1.13.1|==1.13.1|1.13.2|==1.14.0|==1.14.0|==1.14.0|==1.14.0|==1.14.0|==1.14.0|==1.14.0|==1.14.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.15.0|1.7.0|1.7.1|1.8.0|==1.9.0|==1.9.0|==1.9.0|==1.9.0|2.0.0|2.0.0|2.0.0|2.0.0|2.0.0|2.0.0|2.1.0|2.1.0|2.1.0|2.1.0|2.1.0|2.1.0',build='mkl_py37h230818c_0|gpu_py36h55f5790_0|eigen_py37h49b2757_0|mkl_py36hd1d5974_0|gpu_py37h390e234_0|eigen_py37h01553b8_0|eigen_py36h01553b8_0|gpu_py35h6e53903_0|eigen_py35h45df0d8_0|gpu_py37h1afeea4_0|gpu_py36h1afeea4_0|eigen_py37h07d2309_0|eigen_py36h07d2309_0|mkl_py37ha978198_0|gpu_py37h9ee611f_0|gpu_py37h55fc52a_0|gpu_py36h9ee611f_0|eigen_py37hdbc3f0e_0|eigen_py36hdbc3f0e_0|py37_7|py36_8|py36_6|mkl_py37hcaf7020_0|gpu_py37h871c8ca_0|gpu_py37h0fff12a_0|gpu_py36h871c8ca_0|eigen_py37hf8af7b3_0|mkl_py36h81393da_0|mkl_py35h81393da_0|gpu_py35h6e53903_0|eigen_py35h45df0d8_0|eigen_py36h45df0d8_0|gpu_py36h6e53903_0|mkl_py36h81393da_0|eigen_py36h45df0d8_0|gpu_py36h6e53903_0|mkl_py36h81393da_0|eigen_py36h45df0d8_0|gpu_py36h6e53903_0|eigen_py36hf8af7b3_0|gpu_py36h0fff12a_0|mkl_py36hcaf7020_0|py36_4|py36_5|py36_0|gpu_py36h55fc52a_0|mkl_py36ha978198_0|mkl_py36h190a33d_0|mkl_py37h190a33d_0|eigen_py36h45df0d8_0|gpu_py36h6e53903_0|gpu_py36h390e234_0|mkl_py37hd1d5974_0|eigen_py36h49b2757_0|gpu_py37h55f5790_0|mkl_py36h230818c_0']
# Package astor conflicts for:
# tensorflow -> astor[version='>=0.6.0']
